# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character_name：角色姓名。
# - role：演职员类型，演员或导演。

# %% [markdown]
# ### 读取数据

# %%
import pandas as pd

# %%
original_titles = pd.read_csv(r"D:\数据原料\titles.csv")

# %%
original_cerdits = pd.read_csv(r"D:\数据原料\credits.csv")

# %%
original_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
original_cerdits.head(10)
# Out:
#    person_id       id             name                      character   role
# 0       3748  tm84618   Robert De Niro                  Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster                  Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                            Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel        Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                          Betsy  ACTOR
# 5      32267  tm84618      Peter Boyle                         Wizard  ACTOR
# 6     519612  tm84618   Leonard Harris      Senator Charles Palantine  ACTOR
# 7      29068  tm84618   Diahnne Abbott                Concession Girl  ACTOR
# 8     519613  tm84618      Gino Ardito             Policeman at Rally  ACTOR
# 9       3308  tm84618  Martin Scorsese  Passenger Watching Silhouette  ACTOR

# %% [markdown]
# ### 评估和清理数据

# %%
cleaned_titles = original_titles.copy()

# %%
cleaned_credits = original_cerdits.copy()

# %% [markdown]
# ### 数据整齐度

# %%
cleaned_titles.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm70993                        Life of Brian  MOVIE
# 7   tm14873                          Dirty Harry  MOVIE
# 8  tm119281                     Bonnie and Clyde  MOVIE
# 9   tm98978                      The Blue Lagoon  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
# 5  A British sketch comedy series with the shows ...          1969
# 6  Brian Cohen is an average young Jewish man, bu...          1979
# 7  When a madman dubbed 'Scorpio' terrorizes San ...          1971
# 8  In the 1930s, bored waitress Bonnie Parker fal...          1967
# 9  Two small children and a ship's cook survive a...          1980
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
# 5             TV-14       30                       ['comedy', 'european']
# 6                 R       94                                   ['comedy']
# 7                 R      102              ['thriller', 'action', 'crime']
# 8                 R      110                 ['crime', 'drama', 'action']
# 9                 R      104               ['romance', 'action', 'drama']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
# 5               ['GB']      4.0  tt0063929         8.8     73424.0
# 6               ['GB']      NaN  tt0079470         8.0    395024.0
# 7               ['US']      NaN  tt0066999         7.7    155051.0
# 8               ['US']      NaN  tt0061418         7.7    112048.0
# 9               ['US']      NaN  tt0080453         5.8     69844.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600
# 5           17.617       8.306
# 6           17.770       7.800
# 7           12.817       7.500
# 8           15.687       7.500
# 9           50.324       6.156

# %%
cleaned_titles['genres'][1]
# Out:
# "['drama', 'crime']"

# %% [markdown]
# `genres`本应该是列表，但是这里显示的是字符串，所以要转化为列表，要将其拆开，而且包含多个变量，用Python的内置函数`eval`将列表的字符串转换为列表本身

# %%
cleaned_titles['genres'] = cleaned_titles['genres'].apply(lambda x : eval(x))
cleaned_titles['genres'][1]
# Out:
# ['drama', 'crime']

# %%
cleaned_titles = cleaned_titles.explode('genres')
cleaned_titles.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 3  King Arthur, accompanied by his squire, recrui...          1975
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       51  documentation               ['US']      1.0
# 1                 R      114          drama               ['US']      NaN
# 1                 R      114          crime               ['US']      NaN
# 2                 R      109          drama               ['US']      NaN
# 2                 R      109         action               ['US']      NaN
# 2                 R      109       thriller               ['US']      NaN
# 2                 R      109       european               ['US']      NaN
# 3                PG       91        fantasy               ['GB']      NaN
# 3                PG       91         action               ['GB']      NaN
# 3                PG       91         comedy               ['GB']      NaN
#
#      imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        NaN         NaN         NaN            0.600         NaN
# 1  tt0075314         8.2    808582.0           40.965       8.179
# 1  tt0075314         8.2    808582.0           40.965       8.179
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 3  tt0071853         8.2    534486.0           15.461       7.811
# 3  tt0071853         8.2    534486.0           15.461       7.811
# 3  tt0071853         8.2    534486.0           15.461       7.811

# %% [markdown]
# 同理`production_countries`也是一样的操作

# %%
cleaned_titles['production_countries'][4]
# Out:
# 4    ['GB', 'US']
# 4    ['GB', 'US']
# Name: production_countries, dtype: object

# %%
cleaned_titles['production_countries'] = cleaned_titles['production_countries'].apply(lambda x : eval(x))
cleaned_titles['production_countries']
# Out:
# 0       [US]
# 1       [US]
# 1       [US]
# 2       [US]
# 2       [US]
#         ...
# 5847    [CO]
# 5848    [US]
# 5849      []
# 5849      []
# 5849      []
# Name: production_countries, Length: 15147, dtype: object

# %%
cleaned_titles = cleaned_titles.explode('production_countries')
cleaned_titles.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 3  King Arthur, accompanied by his squire, recrui...          1975
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       51  documentation                   US      1.0
# 1                 R      114          drama                   US      NaN
# 1                 R      114          crime                   US      NaN
# 2                 R      109          drama                   US      NaN
# 2                 R      109         action                   US      NaN
# 2                 R      109       thriller                   US      NaN
# 2                 R      109       european                   US      NaN
# 3                PG       91        fantasy                   GB      NaN
# 3                PG       91         action                   GB      NaN
# 3                PG       91         comedy                   GB      NaN
#
#      imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        NaN         NaN         NaN            0.600         NaN
# 1  tt0075314         8.2    808582.0           40.965       8.179
# 1  tt0075314         8.2    808582.0           40.965       8.179
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 3  tt0071853         8.2    534486.0           15.461       7.811
# 3  tt0071853         8.2    534486.0           15.461       7.811
# 3  tt0071853         8.2    534486.0           15.461       7.811

# %% [markdown]
# ### 数据干净度

# %%
cleaned_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17818 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17818 non-null  object
#  1   title                 17817 non-null  object
#  2   type                  17818 non-null  object
#  3   description           17790 non-null  object
#  4   release_year          17818 non-null  int64
#  5   age_certification     10889 non-null  object
#  6   runtime               17818 non-null  int64
#  7   genres                17755 non-null  object
#  8   production_countries  17439 non-null  object
#  9   seasons               6224 non-null   float64
#  10  imdb_id               17116 non-null  object
#  11  imdb_score            16976 non-null  float64
#  12  imdb_votes            16945 non-null  float64
#  13  tmdb_popularity       17663 non-null  float64
#  14  tmdb_score            17241 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 2.2+ MB

# %%
cleaned_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %%
cleaned_titles["release_year"] = pd.to_datetime(cleaned_titles["release_year"],format = "%Y")
cleaned_titles["release_year"]
# Out:
# 0      1945-01-01
# 1      1976-01-01
# 1      1976-01-01
# 2      1972-01-01
# 2      1972-01-01
#           ...
# 5847   2021-01-01
# 5848   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# Name: release_year, Length: 17818, dtype: datetime64[ns]

# %%
cleaned_credits["person_id"] = cleaned_credits["person_id"].astype("str")
cleaned_credits["person_id"]
# Out:
# 0           3748
# 1          14658
# 2           7064
# 3           3739
# 4          48933
#           ...
# 77796     736339
# 77797     399499
# 77798     373198
# 77799     378132
# 77800    1950416
# Name: person_id, Length: 77801, dtype: object

# %% [markdown]
# ### 评估缺失数据

# %% [markdown]
# `genres`,`imdb_score`需要删除空缺值，先对`genres`进行操作

# %%
cleaned_titles.query("genres.isnull()")
# Out:
#              id                                      title   type  \
# 212    tm255589                              One Last Shot  MOVIE
# 619    tm341561                    Like Twenty Impossibles  MOVIE
# 632     ts86241               Le Robe De Mariage Des Cieux   SHOW
# 636    tm404676                       To and from New York  MOVIE
# 637     tm89054                        Osuofia in London 2  MOVIE
# ...         ...                                        ...    ...
# 5799  tm1040959                 The Circle: The Afterparty  MOVIE
# 5802   ts302434    Plastic Cup Boyz: Laughing My Mask Off!   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description release_year  \
# 212   In this low-budget short film, two best buddie...   1998-01-01
# 619   Occupied Palestine: A serene landscape now poc...   2003-01-01
# 632   It was with much difficulty that Ai Qing was a...   2004-01-01
# 636   While covering a story in New York City, a Sea...   2006-01-01
# 637   Osuofia return to his Nigerian village with a ...   2004-01-01
# ...                                                 ...          ...
# 5799  Stars of The Circle drop by to discuss Season ...   2021-01-01
# 5802  Comedy collective The Plastic Cup Boyz pour ou...   2021-01-01
# 5840  In 14th-century Mali, an ambitious young royal...   2022-01-01
# 5844  The stars of "Bling Empire" discuss the show's...   2021-01-01
# 5848  Jamie Foxx, David Alan Grier and more from the...   2021-01-01
#
#      age_certification  runtime genres production_countries  seasons imdb_id  \
# 212                NaN       30    NaN                  NaN      NaN     NaN
# 619                NaN       16    NaN                   PS      NaN     NaN
# 632              TV-MA       63    NaN                  NaN      1.0     NaN
# 636                NaN       82    NaN                   US      NaN     NaN
# 637                NaN       72    NaN                   XX      NaN     NaN
# ...                ...      ...    ...                  ...      ...     ...
# 5799               NaN       35    NaN                   US      NaN     NaN
# 5802               NaN       33    NaN                  NaN      1.0     NaN
# 5840               NaN       26    NaN                  NaN      NaN     NaN
# 5844               NaN       35    NaN                   US      NaN     NaN
# 5848             PG-13       37    NaN                   US      NaN     NaN
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 212          NaN         NaN            1.890         5.2
# 619          NaN         NaN            0.812         6.5
# 632          NaN         NaN            0.600         NaN
# 636          NaN         NaN            1.401         5.8
# 637          NaN         NaN            1.091         NaN
# ...          ...         ...              ...         ...
# 5799         NaN         NaN            1.882        10.0
# 5802         NaN         NaN            0.683         NaN
# 5840         NaN         NaN            1.179         7.0
# 5844         NaN         NaN              NaN         NaN
# 5848         NaN         NaN            1.296        10.0
#
# [63 rows x 15 columns]

# %%
cleaned_titles = cleaned_titles.dropna(subset = ["genres"])
cleaned_titles["genres"].isnull().sum()
# Out:
# np.int64(0)

# %%
cleaned_titles = cleaned_titles.dropna(subset = ["imdb_score"])
cleaned_titles["imdb_score"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 处理重复数据

# %%
cleaned_titles.duplicated().sum()
# Out:
# np.int64(0)

# %%
cleaned_credits.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 并没有发现重复的值

# %% [markdown]
# ### 处理不一致数据

# %% [markdown]
# `production_countries`可能存在不一致

# %%
cleaned_titles["genres"].value_counts()
# Out:
# genres
# drama            3357
# comedy           2419
# thriller         1446
# action           1339
# romance          1080
# crime            1066
# documentation     981
# family            769
# animation         732
# fantasy           727
# european          679
# scifi             647
# horror            438
# history           336
# music             266
# reality           226
# war               221
# sport             188
# western            53
# Name: count, dtype: int64

# %% [markdown]
# 可能存在空字符串，可以删去·

# %%
cleaned_titles = cleaned_titles.query('genres != ""')
cleaned_titles.query('genres == ""')
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
cleaned_titles["production_countries"].value_counts()
# Out:
# production_countries
# US    5648
# IN    1610
# GB    1068
# JP    1046
# FR     720
#       ...
# CU       1
# LK       1
# GT       1
# AF       1
# FO       1
# Name: count, Length: 108, dtype: int64

# %% [markdown]
# 不能观察，要提高观察上限

# %%
with pd.option_context('display.max_rows',None):
     print(cleaned_titles["production_countries"].value_counts())
# Out:
# production_countries
# US         5648
# IN         1610
# GB         1068
# JP         1046
# FR          720
# ES          637
# KR          637
# CA          608
# DE          383
# CN          295
# MX          264
# IT          224
# BR          221
# AU          217
# TR          195
# PH          192
# AR          150
# ID          149
# BE          148
# TW          133
# NG          131
# PL          126
# ZA          103
# HK          102
# NL          102
# CO           94
# EG           93
# DK           89
# TH           87
# SE           81
# LB           70
# NO           68
# AE           52
# IE           49
# SG           47
# XX           43
# IL           42
# RU           41
# CL           35
# CH           33
# PS           32
# BG           31
# MY           30
# SA           28
# IS           28
# AT           28
# NZ           27
# LU           27
# PE           26
# RO           25
# QA           24
# CZ           22
# JO           19
# FI           18
# HU           18
# UY           15
# MA           15
# PT           14
# KH           10
# KW           10
# PR            9
# PK            9
# VN            8
# UA            8
# MT            8
# SU            7
# TN            7
# IR            7
# CD            7
# LT            7
# KE            6
# GH            6
# AL            6
# SN            6
# IQ            5
# MU            5
# CY            5
# TZ            4
# KN            4
# SY            4
# MC            4
# IO            4
# GR            4
# DZ            3
# HR            3
# BS            3
# AO            3
# GL            3
# BD            3
# CM            3
# PY            3
# BF            2
# KG            2
# BY            2
# VE            2
# MW            2
# RS            2
# VA            2
# BT            2
# ZW            2
# Lebanon       1
# NP            1
# GE            1
# CU            1
# LK            1
# GT            1
# AF            1
# FO            1
# Name: count, dtype: int64

# %% [markdown]
# 发现`Lebanon`与`LB`表示的数据是一样的

# %%
cleaned_titles["production_countries"] = cleaned_titles["production_countries"].replace({"Lebanon":"LB"})
with pd.option_context('display.max_rows',None):
    print(cleaned_titles.explode('production_countries')['production_countries'].value_counts())
# Out:
# production_countries
# US    5648
# IN    1610
# GB    1068
# JP    1046
# FR     720
# ES     637
# KR     637
# CA     608
# DE     383
# CN     295
# MX     264
# IT     224
# BR     221
# AU     217
# TR     195
# PH     192
# AR     150
# ID     149
# BE     148
# TW     133
# NG     131
# PL     126
# ZA     103
# HK     102
# NL     102
# CO      94
# EG      93
# DK      89
# TH      87
# SE      81
# LB      71
# NO      68
# AE      52
# IE      49
# SG      47
# XX      43
# IL      42
# RU      41
# CL      35
# CH      33
# PS      32
# BG      31
# MY      30
# SA      28
# AT      28
# IS      28
# NZ      27
# LU      27
# PE      26
# RO      25
# QA      24
# CZ      22
# JO      19
# FI      18
# HU      18
# MA      15
# UY      15
# PT      14
# KW      10
# KH      10
# PK       9
# PR       9
# UA       8
# VN       8
# MT       8
# SU       7
# CD       7
# TN       7
# LT       7
# IR       7
# GH       6
# SN       6
# AL       6
# KE       6
# IQ       5
# MU       5
# CY       5
# TZ       4
# SY       4
# MC       4
# IO       4
# KN       4
# GR       4
# BD       3
# BS       3
# DZ       3
# GL       3
# AO       3
# CM       3
# HR       3
# PY       3
# BF       2
# VE       2
# BY       2
# MW       2
# RS       2
# VA       2
# BT       2
# ZW       2
# KG       2
# NP       1
# GE       1
# CU       1
# LK       1
# GT       1
# AF       1
# FO       1
# Name: count, dtype: int64

# %% [markdown]
# `role`可能存在不一致数据

# %%
cleaned_credits["role"].value_counts()
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %% [markdown]
# 从以上输出结果来看，`role`只有两种可能的值，`ACTOR`或`DIRECTOR`，不存在不一致数据。我们可以把这列的类型转换为`Category`，好处是比字符串类型更节约内存空间，也能表明说值的类型有限。

# %%
cleaned_credits["role"] = cleaned_credits["role"].astype('category')
cleaned_credits["role"]
# Out:
# 0           ACTOR
# 1           ACTOR
# 2           ACTOR
# 3           ACTOR
# 4           ACTOR
#            ...
# 77796       ACTOR
# 77797       ACTOR
# 77798       ACTOR
# 77799       ACTOR
# 77800    DIRECTOR
# Name: role, Length: 77801, dtype: category
# Categories (2, object): ['ACTOR', 'DIRECTOR']

# %% [markdown]
# ### 评估无效和错误数据

# %%
cleaned_titles.describe()
# Out:
#                         release_year       runtime      seasons    imdb_score  \
# count                          16970  16970.000000  5954.000000  16970.000000
# mean   2015-11-14 22:42:51.974072064     80.912552     2.455492      6.514207
# min              1954-01-01 00:00:00      0.000000     1.000000      1.500000
# 25%              2015-01-01 00:00:00     45.000000     1.000000      5.800000
# 50%              2018-01-01 00:00:00     90.000000     2.000000      6.600000
# 75%              2020-01-01 00:00:00    107.000000     3.000000      7.300000
# max              2022-01-01 00:00:00    225.000000    42.000000      9.500000
# std                              NaN     39.596172     2.869428      1.131095
#
#          imdb_votes  tmdb_popularity    tmdb_score
# count  1.694100e+04     16842.000000  16515.000000
# mean   3.281655e+04        29.396307      6.846933
# min    5.000000e+00         0.600000      1.000000
# 25%    7.800000e+02         4.070000      6.200000
# 50%    3.508000e+03        10.195000      6.900000
# 75%    1.697800e+04        23.639000      7.500000
# max    2.294231e+06      2274.044000     10.000000
# std    1.141492e+05        93.178235      1.078831

# %% [markdown]
# `runtime`的最小值存在错误数据，`0`，但是似乎对此次分析目的并没有什么影响，所以可以保留

# %% [markdown]
# ## 整理数据

# %%
cleaned_titles
# Out:
#              id                               title   type  \
# 1       tm84618                         Taxi Driver  MOVIE
# 1       tm84618                         Taxi Driver  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# ...         ...                                 ...    ...
# 5846   tm898842                         C/O Kaadhal  MOVIE
# 5847  tm1059008                             Lokillo  MOVIE
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description release_year  \
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# 2     Intent on seeing the Cahulawassee River before...   1972-01-01
# 2     Intent on seeing the Cahulawassee River before...   1972-01-01
# 2     Intent on seeing the Cahulawassee River before...   1972-01-01
# ...                                                 ...          ...
# 5846  A heart warming film that explores the concept...   2021-01-01
# 5847  A controversial TV host and comedian who has b...   2021-01-01
# 5849  With winter behind them, Bheem and his townspe...   2021-01-01
# 5849  With winter behind them, Bheem and his townspe...   2021-01-01
# 5849  With winter behind them, Bheem and his townspe...   2021-01-01
#
#      age_certification  runtime     genres production_countries  seasons  \
# 1                    R      114      drama                   US      NaN
# 1                    R      114      crime                   US      NaN
# 2                    R      109      drama                   US      NaN
# 2                    R      109     action                   US      NaN
# 2                    R      109   thriller                   US      NaN
# ...                ...      ...        ...                  ...      ...
# 5846               NaN      134      drama                  NaN      NaN
# 5847               NaN       90     comedy                   CO      NaN
# 5849               NaN        7     family                  NaN      1.0
# 5849               NaN        7  animation                  NaN      1.0
# 5849               NaN        7     comedy                  NaN      1.0
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1      tt0075314         8.2    808582.0           40.965       8.179
# 1      tt0075314         8.2    808582.0           40.965       8.179
# 2      tt0068473         7.7    107673.0           10.010       7.300
# 2      tt0068473         7.7    107673.0           10.010       7.300
# 2      tt0068473         7.7    107673.0           10.010       7.300
# ...          ...         ...         ...              ...         ...
# 5846  tt11803618         7.7       348.0              NaN         NaN
# 5847  tt14585902         3.8        68.0           26.005       6.300
# 5849  tt13711094         7.8        18.0            2.289      10.000
# 5849  tt13711094         7.8        18.0            2.289      10.000
# 5849  tt13711094         7.8        18.0            2.289      10.000
#
# [16970 rows x 15 columns]

# %%
cleaned_credits
# Out:
#       person_id         id                name                character  \
# 0          3748    tm84618      Robert De Niro            Travis Bickle
# 1         14658    tm84618        Jodie Foster            Iris Steensma
# 2          7064    tm84618       Albert Brooks                      Tom
# 3          3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4         48933    tm84618     Cybill Shepherd                    Betsy
# ...         ...        ...                 ...                      ...
# 77796    736339  tm1059008    Adelaida Buscato                María Paz
# 77797    399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798    373198  tm1059008         Inés Prieto                    Fanny
# 77799    378132  tm1059008        Isabel Gaona                   Cacica
# 77800   1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# 4         ACTOR
# ...         ...
# 77796     ACTOR
# 77797     ACTOR
# 77798     ACTOR
# 77799     ACTOR
# 77800  DIRECTOR
#
# [77801 rows x 5 columns]

# %%
credits_with_titles = pd.merge(cleaned_credits,cleaned_titles,on = "id",how = "inner")

# %% [markdown]
# 导演不在我们分析范围内

# %%
actor_with_titles = credits_with_titles.query('role == "ACTOR"')

# %%
groupby_genres_and_person_id = credits_with_titles.groupby(["genres","person_id"])

# %%
imdb_score_groupby_genres_and_person_id = groupby_genres_and_person_id["imdb_score"].mean()
imdb_score_groupby_genres_and_person_id
# Out:
# genres   person_id
# action   1000         6.866667
#          100007       7.000000
#          100013       6.400000
#          100019       6.500000
#          100020       6.500000
#                         ...
# western  993735       6.500000
#          998673       7.300000
#          998674       7.300000
#          998675       7.300000
#          99940        4.000000
# Name: imdb_score, Length: 177322, dtype: float64

# %% [markdown]
# 可以使用`reset_index`对层次化索引进行重置

# %%
imdb_score_groupby_genres_and_person_id_df = imdb_score_groupby_genres_and_person_id.reset_index()
imdb_score_groupby_genres_and_person_id_df
# Out:
#          genres person_id  imdb_score
# 0        action      1000    6.866667
# 1        action    100007    7.000000
# 2        action    100013    6.400000
# 3        action    100019    6.500000
# 4        action    100020    6.500000
# ...         ...       ...         ...
# 177317  western    993735    6.500000
# 177318  western    998673    7.300000
# 177319  western    998674    7.300000
# 177320  western    998675    7.300000
# 177321  western     99940    4.000000
#
# [177322 rows x 3 columns]

# %% [markdown]
# 现在针对流派和演员分组的IMDB评分数据已经整理好，可以进入后续的分析步骤了。
#
# 但我们当前可以继续做一些数据整理，比如对上面的结果再次进行分组，找出各个流派里演员作品最高的平均评分是多少、最高评分对应的演员名字是什么。
#
# 要得到这一结果，我们需要再次用`genres`进行分组，然后提取出`imdb_score`变量，计算其最大值。

# %%
genres_max_score = imdb_score_groupby_genres_and_person_id_df.groupby('genres')["imdb_score"].max()
genres_max_score
# Out:
# genres
# action           9.3
# animation        9.3
# comedy           9.2
# crime            9.5
# documentation    9.1
# drama            9.5
# european         8.9
# family           9.3
# fantasy          9.3
# history          9.1
# horror           9.0
# music            8.8
# reality          8.9
# romance          9.2
# scifi            9.3
# sport            9.1
# thriller         9.5
# war              8.8
# western          8.9
# Name: imdb_score, dtype: float64

# %%
genres_max_score_with_person_id = pd.merge(genres_max_score,imdb_score_groupby_genres_and_person_id_df,on = ["genres","imdb_score"])
genres_max_score_with_person_id
# Out:
#       genres  imdb_score person_id
# 0     action         9.3     12790
# 1     action         9.3      1303
# 2     action         9.3     21033
# 3     action         9.3    336830
# 4     action         9.3     86591
# ..       ...         ...       ...
# 136      war         8.8    826547
# 137  western         8.9     22311
# 138  western         8.9     28166
# 139  western         8.9     28180
# 140  western         8.9     93017
#
# [141 rows x 3 columns]

# %%
actor_id_with_names = cleaned_credits[['person_id','name']]
actor_id_with_names
# Out:
#       person_id                name
# 0          3748      Robert De Niro
# 1         14658        Jodie Foster
# 2          7064       Albert Brooks
# 3          3739       Harvey Keitel
# 4         48933     Cybill Shepherd
# ...         ...                 ...
# 77796    736339    Adelaida Buscato
# 77797    399499  Luz Stella Luengas
# 77798    373198         Inés Prieto
# 77799    378132        Isabel Gaona
# 77800   1950416      Julian Gaviria
#
# [77801 rows x 2 columns]

# %%
genres_max_score_with_actor_name = pd.merge(genres_max_score_with_person_id,actor_id_with_names,on = "person_id")
genres_max_score_with_actor_name
# Out:
#       genres  imdb_score person_id            name
# 0     action         9.3     12790     Olivia Hack
# 1     action         9.3     12790     Olivia Hack
# 2     action         9.3     12790     Olivia Hack
# 3     action         9.3      1303   Jessie Flower
# 4     action         9.3     21033      Zach Tyler
# ..       ...         ...       ...             ...
# 288  western         8.9     28180  Unsho Ishizuka
# 289  western         8.9     28180  Unsho Ishizuka
# 290  western         8.9     28180  Unsho Ishizuka
# 291  western         8.9     28180  Unsho Ishizuka
# 292  western         8.9     93017        Aoi Tada
#
# [293 rows x 4 columns]

# %%
genres_max_score_with_actor_name = genres_max_score_with_actor_name.sort_values("genres").reset_index().drop("index",axis = 1)
genres_max_score_with_actor_name
# Out:
#       genres  imdb_score person_id             name
# 0     action         9.3     12790      Olivia Hack
# 1     action         9.3     12790      Olivia Hack
# 2     action         9.3     12790      Olivia Hack
# 3     action         9.3      1303    Jessie Flower
# 4     action         9.3     21033       Zach Tyler
# ..       ...         ...       ...              ...
# 288  western         8.9     22311  Koichi Yamadera
# 289  western         8.9     22311  Koichi Yamadera
# 290  western         8.9     28180   Unsho Ishizuka
# 291  western         8.9     22311  Koichi Yamadera
# 292  western         8.9     93017         Aoi Tada
#
# [293 rows x 4 columns]

# %%
cleaned_titles.to_csv("titles.csv",index = False)

# %%
pd.read_csv("titles.csv").head(10)
# Out:
#          id                            title   type  \
# 0   tm84618                      Taxi Driver  MOVIE
# 1   tm84618                      Taxi Driver  MOVIE
# 2  tm154986                      Deliverance  MOVIE
# 3  tm154986                      Deliverance  MOVIE
# 4  tm154986                      Deliverance  MOVIE
# 5  tm154986                      Deliverance  MOVIE
# 6  tm127384  Monty Python and the Holy Grail  MOVIE
# 7  tm127384  Monty Python and the Holy Grail  MOVIE
# 8  tm127384  Monty Python and the Holy Grail  MOVIE
# 9  tm120801                  The Dirty Dozen  MOVIE
#
#                                          description release_year  \
# 0  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 2  Intent on seeing the Cahulawassee River before...   1972-01-01
# 3  Intent on seeing the Cahulawassee River before...   1972-01-01
# 4  Intent on seeing the Cahulawassee River before...   1972-01-01
# 5  Intent on seeing the Cahulawassee River before...   1972-01-01
# 6  King Arthur, accompanied by his squire, recrui...   1975-01-01
# 7  King Arthur, accompanied by his squire, recrui...   1975-01-01
# 8  King Arthur, accompanied by his squire, recrui...   1975-01-01
# 9  12 American military prisoners in World War II...   1967-01-01
#
#   age_certification  runtime    genres production_countries  seasons  \
# 0                 R      114     drama                   US      NaN
# 1                 R      114     crime                   US      NaN
# 2                 R      109     drama                   US      NaN
# 3                 R      109    action                   US      NaN
# 4                 R      109  thriller                   US      NaN
# 5                 R      109  european                   US      NaN
# 6                PG       91   fantasy                   GB      NaN
# 7                PG       91    action                   GB      NaN
# 8                PG       91    comedy                   GB      NaN
# 9               NaN      150       war                   GB      NaN
#
#      imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0  tt0075314         8.2    808582.0           40.965       8.179
# 1  tt0075314         8.2    808582.0           40.965       8.179
# 2  tt0068473         7.7    107673.0           10.010       7.300
# 3  tt0068473         7.7    107673.0           10.010       7.300
# 4  tt0068473         7.7    107673.0           10.010       7.300
# 5  tt0068473         7.7    107673.0           10.010       7.300
# 6  tt0071853         8.2    534486.0           15.461       7.811
# 7  tt0071853         8.2    534486.0           15.461       7.811
# 8  tt0071853         8.2    534486.0           15.461       7.811
# 9  tt0061578         7.7     72662.0           20.398       7.600

# %%
cleaned_credits.to_csv("credits.csv",index = False)

# %%
pd.read_csv("credits.csv")
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# 4         ACTOR
# ...         ...
# 77796     ACTOR
# 77797     ACTOR
# 77798     ACTOR
# 77799     ACTOR
# 77800  DIRECTOR
#
# [77801 rows x 5 columns]
